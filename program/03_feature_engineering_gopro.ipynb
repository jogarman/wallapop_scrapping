# %% [markdown]
# ## Featuring engineering
# obtengo variables como el modelo de la gopro

# %%
import os
import pandas as pd
import re
from datetime import datetime

# %%
carpeta = "../2_datos_por_fecha"
fecha = datetime.now().strftime("%Y%m%d")
#fecha = "20250102"

# %%
df = pd.read_csv(carpeta + '/' + "gopro_" + fecha + '.csv', index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df = pd.read_csv(carpeta + '/' + "gopro_" + fecha + '.csv', index_col=0)
#
# File c:\Users\ACER\Desktop\Proyectos python\wallapop_scrapping\.env\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\ACER\Desktop\Proyectos python\wallapop_scrapping\.env\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\ACER\Desktop\Proyectos python\wallapop_scrapping\.env\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\ACER\Desktop\Proyectos python\wallapop_scrapping\.env\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\ACER\Desktop\Proyectos python\wallapop_scrapping\.env\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../2_datos_por_fecha/gopro_20250206.csv'

# %%
df
# Out:
#             id                                             nombre  precio  \
# 0   1097437600                               gopro 10 hero black   230,00
# 1   1094003898                                gopro hero 10 black  320,00
# 2   1090787536                                           gopro 10  248,00
# 3   1091568974                                     gopro 10 black  249,00
# 4   1095343902                               go pro hero 10 black  170,00
# 5   1091711762                   gopro hero 10 black y accesorios  240,00
# 6   1086977927                                gopro hero black 10  200,00
# 7   1078290389                               gopro hero 10 black   229,00
# 8   1069932964                                     gopro 10 black  160,00
# 9   1071003713                                      gopro hero 10  200,00
# 10  1051674571                      cambio panasonic por gopro 10  250,00
# 11  1048036050                         gopro hero 10 + accesorios  230,00
# 12  1037670264                               gopro hero 10 black   330,00
# 13   997314133                                          gopro 10   180,00
# 14  1027999409                gopro hero 10 black + pack max lens  300,00
# 15   936206770            gopro hero 10 con accesorios a estrenar  260,00
# 16   934696940                                gopro hero 10 black  280,00
# 17  1085625687                                gopro hero 10 black  375,00
# 18  1097904263                                      gopro hero 10   90,00
# 19  1092597688                                     gopro 10 black  195,00
# 20  1096049607                gopro hero 10 black con accesorios   400,00
# 21  1086866366                              go pro hero 10 black   250,00
# 22  1080565222                             camara go pro 10 black  350,00
# 23  1030106635                                      gopro hero 10  270,00
# 24  1094909743                               go pro hero 11 black  270,00
# 25  1094903053                              go pro hero 11 black   270,00
# 26  1083902061                               go pro 11 como nueva  350,00
# 27  1061806929                        ⚠️gopro hero 11 naked nueva  370,00
# 28  1097081705                               gopro hero 12 black   320,00
# 29  1095462963                       gopro 12 pack crator edition  400,00
# 30  1072590194                                           gopro 12  310,00
# 31  1050597462                                gopro hero 12 naked  300,00
# 32  1066722758                                         go pro 12   375,00
# 33  1047653797      gopro hero 12 creator pack + mod max lens 2.0  480,00
# 34  1098125239  camara gopro hero 12 black + kit accesorios 20...  299,95
# 35  1079605964                                           gopro 12  350,00
# 36  1095476347                                      gopro hero 12  280,00
# 37  1094196062                                gopro hero 12 black  280,00
# 38  1081465646                        ⚠️gopro hero 12 naked nueva  400,00
# 39  1050151212                                      gopro hero 12  350,00
# 40  1094367879                                     gopro 13 black  350,00
#
#             estado scrap_locat  dist_scrap_locat  reservado  \
# 0   as_good_as_new      madrid                60      False
# 1   as_good_as_new      madrid                60      False
# 2   as_good_as_new      madrid                60      False
# 3   as_good_as_new      madrid                60      False
# 4   as_good_as_new      madrid                60      False
# 5   as_good_as_new      madrid                60      False
# 6   as_good_as_new      madrid                60      False
# 7   as_good_as_new      madrid                60      False
# 8   as_good_as_new      madrid                60      False
# 9   as_good_as_new      madrid                60      False
# 10  as_good_as_new      madrid                60      False
# 11  as_good_as_new      madrid                60      False
# 12  as_good_as_new      madrid                60      False
# 13  as_good_as_new      madrid                60      False
# 14  as_good_as_new      madrid                60      False
# 15  as_good_as_new      madrid                60      False
# 16  as_good_as_new      madrid                60      False
# 17            good      madrid                60      False
# 18             new      madrid                60      False
# 19             new      madrid                60      False
# 20             new      madrid                60      False
# 21             new      madrid                60      False
# 22             new      madrid                60      False
# 23             new      madrid                60      False
# 24             new      madrid                60      False
# 25             new      madrid                60      False
# 26             new      madrid                60      False
# 27             new      madrid                60      False
# 28  as_good_as_new      madrid                60      False
# 29  as_good_as_new      madrid                60      False
# 30  as_good_as_new      madrid                60      False
# 31  as_good_as_new      madrid                60      False
# 32  as_good_as_new      madrid                60      False
# 33  as_good_as_new      madrid                60      False
# 34            good      madrid                60      False
# 35            good      madrid                60      False
# 36             new      madrid                60      False
# 37             new      madrid                60      False
# 38             new      madrid                60      False
# 39             new      madrid                60      False
# 40             new      madrid                60      False
#
#                                                   url     fecha
# 0   https://es.wallapop.com/item/gopro-10-hero-bla...  20250205
# 1   https://es.wallapop.com/item/gopro-hero-10-bla...  20250205
# 2    https://es.wallapop.com/item/gopro-10-1090787536  20250205
# 3   https://es.wallapop.com/item/gopro-10-black-10...  20250205
# 4   https://es.wallapop.com/item/go-pro-hero-10-bl...  20250205
# 5   https://es.wallapop.com/item/gopro-hero-10-bla...  20250205
# 6   https://es.wallapop.com/item/gopro-hero-black-...  20250205
# 7   https://es.wallapop.com/item/gopro-hero-10-bla...  20250205
# 8   https://es.wallapop.com/item/gopro-10-black-10...  20250205
# 9   https://es.wallapop.com/item/gooro-hero-10-107...  20250205
# 10  https://es.wallapop.com/item/cambio-panasonic-...  20250205
# 11  https://es.wallapop.com/item/gopro-hero-10---a...  20250205
# 12  https://es.wallapop.com/item/gopro-hero-10-bla...  20250205
# 13    https://es.wallapop.com/item/gopro-10-997314133  20250205
# 14  https://es.wallapop.com/item/gopro-hero-10-bla...  20250205
# 15  https://es.wallapop.com/item/gopro-10-con-acce...  20250205
# 16  https://es.wallapop.com/item/gopro-hero-10-bla...  20250205
# 17  https://es.wallapop.com/item/gopro-hero-10-bla...  20250205
# 18  https://es.wallapop.com/item/gopro-hero-10-109...  20250205
# 19  https://es.wallapop.com/item/gopro-10black-109...  20250205
# 20  https://es.wallapop.com/item/gopro-hero-10-bla...  20250205
# 21  https://es.wallapop.com/item/go-pro-hero-10-bl...  20250205
# 22  https://es.wallapop.com/item/camara-go-pro-10-...  20250205
# 23  https://es.wallapop.com/item/gopro-hero-10-103...  20250205
# 24  https://es.wallapop.com/item/go-pro-hero-11-bl...  20250205
# 25  https://es.wallapop.com/item/go-pro-hero-11-bl...  20250205
# 26  https://es.wallapop.com/item/go-pro-11-como-nu...  20250205
# 27  https://es.wallapop.com/item/gopro-hero-11-nak...  20250205
# 28  https://es.wallapop.com/item/gopro-hero-12-bla...  20250205
# 29  https://es.wallapop.com/item/gopro-12-pack-109...  20250205
# 30   https://es.wallapop.com/item/gopro-12-1072590194  20250205
# 31  https://es.wallapop.com/item/gopro-hero-12-nak...  20250205
# 32  https://es.wallapop.com/item/go-pro-12-1066722758  20250205
# 33  https://es.wallapop.com/item/full-equip-go-pro...  20250205
# 34  https://es.wallapop.com/item/camara-gopro-hero...  20250205
# 35   https://es.wallapop.com/item/gopro-12-1079605964  20250205
# 36  https://es.wallapop.com/item/gopro-hero-12-109...  20250205
# 37  https://es.wallapop.com/item/gopro-hero-12-bla...  20250205
# 38  https://es.wallapop.com/item/gopro-12-naked-10...  20250205
# 39  https://es.wallapop.com/item/gopro-hero-12-105...  20250205
# 40  https://es.wallapop.com/item/gopro-13-black-10...  20250205

# %%
# Asigno columnas MODELO, MEMORIA, COLOR, BATERIA....

# Creo una columna en la que pongo que iphone es (14, 15 o 16..) y que tipo. 
# Gen
# Model
for index in range(len(df)):
    df['gen'] = 'vacio'
    df['modelo'] = 'modelo'

def asignar_gen(nombre):
    if '8' in nombre:
        return '8'
    elif '9' in nombre:
        return '9'
    elif '10' in nombre:
        return '10'
    elif '11' in nombre:
        return '11'
    elif '12' in nombre:
        return '12'
    elif '13' in nombre:
        return '13'
    elif '14' in nombre:
        return '14'
    return "n/a"

# Función para asignar el valor de la columna "modelo"
def asignar_modelo(nombre):
    if 'pro max' in nombre.lower():
        return 'pro max'
    elif 'pro' in nombre.lower():
        return 'pro'
    elif 'plus' in nombre.lower():
        return 'plus'
    else:
        return 'basic'

def asignar_memoria(nombre):
    if '128' in nombre.lower():
        return '128'
    elif '256' in nombre.lower():
        return '256'
    elif '512' in nombre.lower():
        return '512'
    elif '1tb' in nombre.lower():
        return '1tb'
    else:
        return 'n/a'
colores_iphones = ["Púrpura", "Verde", "Blanco", "Azul", "Negro", "Rojo", "Grafito", "Plata", "Oro", "Morado", "titanio", "Ultramarino", 'rojo', 'azul', 'negro', 'blanco', 'verde', 'amarillo', 'rosado', 'rosa', 'gris', 'morado', 'naranja']
# Imprimir todos los colores
def tiene_color(nombre):
    return any(color in nombre.lower() for color in colores_iphones)
def tiene_emojis(nombre):
    return bool(re.search(r'[^\w\s,]', nombre))  # Busca caracteres no alfanuméricos que son emojis
def tiene_vendo(nombre):
    return 'vendo' in nombre.lower()
def tiene_revisado(nombre):
    return 'revisado' in nombre.lower()
    
# Función para asignar el valor de la columna "bateria"
def asignar_bateria(nombre):
    # Buscar números entre 80 y 100 en el nombre
    bateria = re.findall(r'\b([8-9][0-9]|100)\b', nombre)
    if bateria:
        return int(bateria[0])  # Retorna el primer número que encuentra
    return "n/a"

# Aplicar las funciones al DataFrame
df['gen'] = df['nombre'].apply(asignar_gen)
# df['mod'] = df['nombre'].apply(asignar_modelo)
# df['memoria'] = df['nombre'].apply(asignar_memoria)
# df['bateria'] = df['nombre'].apply(asignar_bateria)
orden_columnas = ['id','fecha', 'gen', 'precio', 'estado', 'nombre', 'scrap_locat' , 'dist_scrap_locat',
    'reservado', 'url']
df = df[orden_columnas]
df
# Out:
#             id     fecha gen  precio          estado  \
# 0   1097437600  20250205  10  230,00  as_good_as_new
# 1   1094003898  20250205  10  320,00  as_good_as_new
# 2   1090787536  20250205  10  248,00  as_good_as_new
# 3   1091568974  20250205  10  249,00  as_good_as_new
# 4   1095343902  20250205  10  170,00  as_good_as_new
# 5   1091711762  20250205  10  240,00  as_good_as_new
# 6   1086977927  20250205  10  200,00  as_good_as_new
# 7   1078290389  20250205  10  229,00  as_good_as_new
# 8   1069932964  20250205  10  160,00  as_good_as_new
# 9   1071003713  20250205  10  200,00  as_good_as_new
# 10  1051674571  20250205  10  250,00  as_good_as_new
# 11  1048036050  20250205  10  230,00  as_good_as_new
# 12  1037670264  20250205  10  330,00  as_good_as_new
# 13   997314133  20250205  10  180,00  as_good_as_new
# 14  1027999409  20250205  10  300,00  as_good_as_new
# 15   936206770  20250205  10  260,00  as_good_as_new
# 16   934696940  20250205  10  280,00  as_good_as_new
# 17  1085625687  20250205  10  375,00            good
# 18  1097904263  20250205  10   90,00             new
# 19  1092597688  20250205  10  195,00             new
# 20  1096049607  20250205  10  400,00             new
# 21  1086866366  20250205  10  250,00             new
# 22  1080565222  20250205  10  350,00             new
# 23  1030106635  20250205  10  270,00             new
# 24  1094909743  20250205  11  270,00             new
# 25  1094903053  20250205  11  270,00             new
# 26  1083902061  20250205  11  350,00             new
# 27  1061806929  20250205  11  370,00             new
# 28  1097081705  20250205  12  320,00  as_good_as_new
# 29  1095462963  20250205  12  400,00  as_good_as_new
# 30  1072590194  20250205  12  310,00  as_good_as_new
# 31  1050597462  20250205  12  300,00  as_good_as_new
# 32  1066722758  20250205  12  375,00  as_good_as_new
# 33  1047653797  20250205  12  480,00  as_good_as_new
# 34  1098125239  20250205   8  299,95            good
# 35  1079605964  20250205  12  350,00            good
# 36  1095476347  20250205  12  280,00             new
# 37  1094196062  20250205  12  280,00             new
# 38  1081465646  20250205  12  400,00             new
# 39  1050151212  20250205  12  350,00             new
# 40  1094367879  20250205  13  350,00             new
#
#                                                nombre scrap_locat  \
# 0                                gopro 10 hero black       madrid
# 1                                 gopro hero 10 black      madrid
# 2                                            gopro 10      madrid
# 3                                      gopro 10 black      madrid
# 4                                go pro hero 10 black      madrid
# 5                    gopro hero 10 black y accesorios      madrid
# 6                                 gopro hero black 10      madrid
# 7                                gopro hero 10 black       madrid
# 8                                      gopro 10 black      madrid
# 9                                       gopro hero 10      madrid
# 10                      cambio panasonic por gopro 10      madrid
# 11                         gopro hero 10 + accesorios      madrid
# 12                               gopro hero 10 black       madrid
# 13                                          gopro 10       madrid
# 14                gopro hero 10 black + pack max lens      madrid
# 15            gopro hero 10 con accesorios a estrenar      madrid
# 16                                gopro hero 10 black      madrid
# 17                                gopro hero 10 black      madrid
# 18                                      gopro hero 10      madrid
# 19                                     gopro 10 black      madrid
# 20                gopro hero 10 black con accesorios       madrid
# 21                              go pro hero 10 black       madrid
# 22                             camara go pro 10 black      madrid
# 23                                      gopro hero 10      madrid
# 24                               go pro hero 11 black      madrid
# 25                              go pro hero 11 black       madrid
# 26                               go pro 11 como nueva      madrid
# 27                        ⚠️gopro hero 11 naked nueva      madrid
# 28                               gopro hero 12 black       madrid
# 29                       gopro 12 pack crator edition      madrid
# 30                                           gopro 12      madrid
# 31                                gopro hero 12 naked      madrid
# 32                                         go pro 12       madrid
# 33      gopro hero 12 creator pack + mod max lens 2.0      madrid
# 34  camara gopro hero 12 black + kit accesorios 20...      madrid
# 35                                           gopro 12      madrid
# 36                                      gopro hero 12      madrid
# 37                                gopro hero 12 black      madrid
# 38                        ⚠️gopro hero 12 naked nueva      madrid
# 39                                      gopro hero 12      madrid
# 40                                     gopro 13 black      madrid
#
#     dist_scrap_locat  reservado  \
# 0                 60      False
# 1                 60      False
# 2                 60      False
# 3                 60      False
# 4                 60      False
# 5                 60      False
# 6                 60      False
# 7                 60      False
# 8                 60      False
# 9                 60      False
# 10                60      False
# 11                60      False
# 12                60      False
# 13                60      False
# 14                60      False
# 15                60      False
# 16                60      False
# 17                60      False
# 18                60      False
# 19                60      False
# 20                60      False
# 21                60      False
# 22                60      False
# 23                60      False
# 24                60      False
# 25                60      False
# 26                60      False
# 27                60      False
# 28                60      False
# 29                60      False
# 30                60      False
# 31                60      False
# 32                60      False
# 33                60      False
# 34                60      False
# 35                60      False
# 36                60      False
# 37                60      False
# 38                60      False
# 39                60      False
# 40                60      False
#
#                                                   url
# 0   https://es.wallapop.com/item/gopro-10-hero-bla...
# 1   https://es.wallapop.com/item/gopro-hero-10-bla...
# 2    https://es.wallapop.com/item/gopro-10-1090787536
# 3   https://es.wallapop.com/item/gopro-10-black-10...
# 4   https://es.wallapop.com/item/go-pro-hero-10-bl...
# 5   https://es.wallapop.com/item/gopro-hero-10-bla...
# 6   https://es.wallapop.com/item/gopro-hero-black-...
# 7   https://es.wallapop.com/item/gopro-hero-10-bla...
# 8   https://es.wallapop.com/item/gopro-10-black-10...
# 9   https://es.wallapop.com/item/gooro-hero-10-107...
# 10  https://es.wallapop.com/item/cambio-panasonic-...
# 11  https://es.wallapop.com/item/gopro-hero-10---a...
# 12  https://es.wallapop.com/item/gopro-hero-10-bla...
# 13    https://es.wallapop.com/item/gopro-10-997314133
# 14  https://es.wallapop.com/item/gopro-hero-10-bla...
# 15  https://es.wallapop.com/item/gopro-10-con-acce...
# 16  https://es.wallapop.com/item/gopro-hero-10-bla...
# 17  https://es.wallapop.com/item/gopro-hero-10-bla...
# 18  https://es.wallapop.com/item/gopro-hero-10-109...
# 19  https://es.wallapop.com/item/gopro-10black-109...
# 20  https://es.wallapop.com/item/gopro-hero-10-bla...
# 21  https://es.wallapop.com/item/go-pro-hero-10-bl...
# 22  https://es.wallapop.com/item/camara-go-pro-10-...
# 23  https://es.wallapop.com/item/gopro-hero-10-103...
# 24  https://es.wallapop.com/item/go-pro-hero-11-bl...
# 25  https://es.wallapop.com/item/go-pro-hero-11-bl...
# 26  https://es.wallapop.com/item/go-pro-11-como-nu...
# 27  https://es.wallapop.com/item/gopro-hero-11-nak...
# 28  https://es.wallapop.com/item/gopro-hero-12-bla...
# 29  https://es.wallapop.com/item/gopro-12-pack-109...
# 30   https://es.wallapop.com/item/gopro-12-1072590194
# 31  https://es.wallapop.com/item/gopro-hero-12-nak...
# 32  https://es.wallapop.com/item/go-pro-12-1066722758
# 33  https://es.wallapop.com/item/full-equip-go-pro...
# 34  https://es.wallapop.com/item/camara-gopro-hero...
# 35   https://es.wallapop.com/item/gopro-12-1079605964
# 36  https://es.wallapop.com/item/gopro-hero-12-109...
# 37  https://es.wallapop.com/item/gopro-hero-12-bla...
# 38  https://es.wallapop.com/item/gopro-12-naked-10...
# 39  https://es.wallapop.com/item/gopro-hero-12-105...
# 40  https://es.wallapop.com/item/gopro-13-black-10...

# %%
# df['tiene_color'] = df['nombre'].apply(tiene_color)
# df['tiene_emojis'] = df['nombre'].apply(tiene_emojis)
# df['tiene_revisado'] = df['nombre'].apply(tiene_revisado)

# %%
carpeta = "../3_feature_engineering"
if not os.path.exists(carpeta):
    os.makedirs(carpeta)
nombre_archivo = f"{carpeta}/gopro_{fecha}.xlsx" # excel ofrece ventajas para abrirlo en tableu. Pero no recuerdo cuales
df = df.reset_index(drop=True) # sin indice
df.to_excel(nombre_archivo, index=False)
print(nombre_archivo, "creado exitosamente")
