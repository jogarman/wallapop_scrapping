# %% [markdown]
# ## Featuring engineering
# obtengo variables como el modelo de la gopro

# %%
import os
import pandas as pd
import re
from datetime import datetime

# %%
carpeta = "2_datos_por_fecha"
fecha = datetime.now().strftime("%Y%m%d")
#fecha = "20250102"

# %%
df = pd.read_csv(carpeta + '/' + "gopro_" + fecha + '.csv', index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv(carpeta + '/' + "gopro_" + fecha + '.csv', index_col=0)
#
# File c:\Users\ACER\Desktop\Proyectos python\wallapop_scrapping\.env\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\ACER\Desktop\Proyectos python\wallapop_scrapping\.env\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\ACER\Desktop\Proyectos python\wallapop_scrapping\.env\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\ACER\Desktop\Proyectos python\wallapop_scrapping\.env\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\ACER\Desktop\Proyectos python\wallapop_scrapping\.env\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '2_datos_por_fecha/gopro_20250119.csv'

# %%
df
# Out:
#             id                                         nombre  precio  \
# 0   1052099071        camara go pro hero 11 black 5.3k 191926  259,95
# 1   1072590194                                       gopro 12  370,00
# 2   1079605964                                       gopro 12  350,00
# 3   1080471539                                  gopro hero 12  300,00
# 4   1083902061                           go pro 11 como nueva  350,00
# 5   1085625687                            gopro hero 10 black  400,00
# 6   1086469969                      go pro hero 11 black mini  200,00
# 7   1086866366                          go pro hero 10 black   250,00
# 8   1086977927                            gopro hero black 10  300,00
# 9   1050597462                            gopro hero 12 naked  300,00
# 10  1078061746        camara go pro hero 11 black 5.3k 197994  259,95
# 11  1078754814                       kit gopro 10 black nueva  300,00
# 12  1079697974                    camara go pro hero 11 black  280,00
# 13  1081465646                    ⚠️gopro hero 12 naked nueva  400,00
# 14  1083654200                                 gopro hero 11   260,00
# 15  1083963942                    gopro hero 10 black edition  190,00
# 16  1050151212                                  gopro hero 12  350,00
# 17  1051932652                                 gopro 11 black  315,00
# 18  1055352107                            gopro hero 11 black  360,00
# 19  1066722758                                     go pro 12   375,00
# 20  1073821636                                 gopro 10 black  185,00
# 21  1079776254                      gopro hero 10 black nueva  195,00
# 22  1082701930             gopro hero 11 black con accesorios  250,00
# 23  1028421251                   gopro hero 12 mas accesorios  499,00
# 24  1061806929                    ⚠️gopro hero 11 naked nueva  370,00
# 25  1071803247                           gopro 10 black nueva  280,00
# 26  1078290389                           gopro hero 10 black   229,00
# 27  1079406835                                 gopro 11 mini   220,00
# 28  1047653797  gopro hero 12 creator pack + mod max lens 2.0  480,00
# 29  1073503955                                gopro 10 black   250,00
# 30  1080359690                                  gopro hero 11  220,00
# 31  1080565222                         camara go pro 10 black  400,00
# 32  1043835923                                       gopro 10  305,00
# 33  1073377586                                 gopro hero 10   230,00
# 34  1074168225               gopro hero 11 black + accesorios  450,00
# 35  1069932964                                 gopro 10 black  170,00
# 36  1070264638                   gopro hero black 11 + extras  315,00
# 37  1065739896                    gopro 11 black + accesorios  300,00
# 38  1075419904             gopro hero black 10 con su estuche  150,00
# 39  1058245981                            gopro 11 hero black  295,00
# 40  1071003713                                  gopro hero 10  200,00
# 41  1049932839                                 gopro 11 black  290,00
# 42  1075203306                                 go pro hero 10  225,00
# 43  1051674571                  cambio panasonic por gopro 10  250,00
# 44  1058979498                          cámara gopro 11 black  350,00
# 45  1044882801                                       gopro 11  350,00
# 46  1073520820                           go pro 10 hero black  300,00
# 47  1041397524                            gopro 11 hero black  240,00
# 48  1048036050                     gopro hero 10 + accesorios  240,00
# 49  1012043733         gopro 11 +volta + media+kit como nuevo  340,00
# 50  1037670264                           gopro hero 10 black   330,00
# 51   939826349                                  gopro hero 11  320,00
# 52   997314133                                      gopro 10   180,00
# 53  1027999409            gopro hero 10 black + pack max lens  300,00
# 54   936206770               gopro 10 + accesorios a estrenar  280,00
# 55   934696940                            gopro hero 10 black  280,00
#
#             estado scrap_locat  dist_scrap_locat  reservado  \
# 0             good      madrid                60      False
# 1   as_good_as_new      madrid                60      False
# 2             good      madrid                60      False
# 3              new      madrid                60      False
# 4              new      madrid                60      False
# 5             good      madrid                60      False
# 6   as_good_as_new      madrid                60      False
# 7              new      madrid                60      False
# 8   as_good_as_new      madrid                60      False
# 9   as_good_as_new      madrid                60      False
# 10            good      madrid                60      False
# 11             new      madrid                60      False
# 12             new      madrid                60      False
# 13             new      madrid                60      False
# 14  as_good_as_new      madrid                60      False
# 15  as_good_as_new      madrid                60      False
# 16             new      madrid                60      False
# 17             new      madrid                60      False
# 18            good      madrid                60      False
# 19  as_good_as_new      madrid                60      False
# 20  as_good_as_new      madrid                60      False
# 21             new      madrid                60      False
# 22  as_good_as_new      madrid                60      False
# 23  as_good_as_new      madrid                60      False
# 24             new      madrid                60      False
# 25             new      madrid                60      False
# 26  as_good_as_new      madrid                60      False
# 27  as_good_as_new      madrid                60      False
# 28  as_good_as_new      madrid                60      False
# 29  as_good_as_new      madrid                60      False
# 30  as_good_as_new      madrid                60      False
# 31             new      madrid                60      False
# 32             new      madrid                60      False
# 33  as_good_as_new      madrid                60      False
# 34  as_good_as_new      madrid                60      False
# 35  as_good_as_new      madrid                60      False
# 36  as_good_as_new      madrid                60      False
# 37  as_good_as_new      madrid                60      False
# 38  as_good_as_new      madrid                60      False
# 39  as_good_as_new      madrid                60      False
# 40  as_good_as_new      madrid                60      False
# 41  as_good_as_new      madrid                60      False
# 42  as_good_as_new      madrid                60      False
# 43  as_good_as_new      madrid                60      False
# 44  as_good_as_new      madrid                60      False
# 45  as_good_as_new      madrid                60      False
# 46  as_good_as_new      madrid                60      False
# 47  as_good_as_new      madrid                60      False
# 48  as_good_as_new      madrid                60      False
# 49  as_good_as_new      madrid                60      False
# 50  as_good_as_new      madrid                60      False
# 51  as_good_as_new      madrid                60      False
# 52  as_good_as_new      madrid                60      False
# 53  as_good_as_new      madrid                60      False
# 54  as_good_as_new      madrid                60      False
# 55  as_good_as_new      madrid                60      False
#
#                                                   url     fecha
# 0   https://es.wallapop.com/item/camara-go-pro-her...  20250110
# 1    https://es.wallapop.com/item/gopro-12-1072590194  20250110
# 2    https://es.wallapop.com/item/gopro-12-1079605964  20250110
# 3   https://es.wallapop.com/item/gopro-hero-12-108...  20250110
# 4   https://es.wallapop.com/item/go-pro-11-como-nu...  20250110
# 5   https://es.wallapop.com/item/gopro-hero-10-bla...  20250110
# 6   https://es.wallapop.com/item/go-pro-hero-11-bl...  20250110
# 7   https://es.wallapop.com/item/go-pro-hero-10-bl...  20250110
# 8   https://es.wallapop.com/item/gopro-hero-black-...  20250110
# 9   https://es.wallapop.com/item/gopro-hero-12-nak...  20250110
# 10  https://es.wallapop.com/item/camara-go-pro-her...  20250110
# 11  https://es.wallapop.com/item/kit-gopro-10-blac...  20250110
# 12  https://es.wallapop.com/item/camara-go-pro-her...  20250110
# 13  https://es.wallapop.com/item/gopro-12-naked-10...  20250110
# 14  https://es.wallapop.com/item/gopro-hero-11-108...  20250110
# 15  https://es.wallapop.com/item/gopro-hero-10-bla...  20250110
# 16  https://es.wallapop.com/item/gopro-hero-12-105...  20250110
# 17  https://es.wallapop.com/item/gopro-11-black-10...  20250110
# 18  https://es.wallapop.com/item/gopro-hero-11-bla...  20250110
# 19  https://es.wallapop.com/item/go-pro-12-1066722758  20250110
# 20  https://es.wallapop.com/item/gopro-10-black-10...  20250110
# 21  https://es.wallapop.com/item/gopro-hero-10-bla...  20250110
# 22  https://es.wallapop.com/item/gopro-hero-11-bla...  20250110
# 23  https://es.wallapop.com/item/gopro-hero-12-mas...  20250110
# 24  https://es.wallapop.com/item/gopro-hero-11-nak...  20250110
# 25  https://es.wallapop.com/item/gopro-10-black-nu...  20250110
# 26  https://es.wallapop.com/item/gopro-hero-10-bla...  20250110
# 27  https://es.wallapop.com/item/gopro-11-mini-107...  20250110
# 28  https://es.wallapop.com/item/full-equip-go-pro...  20250110
# 29  https://es.wallapop.com/item/gopro-10-black-10...  20250110
# 30  https://es.wallapop.com/item/gopro-hero-11-108...  20250110
# 31  https://es.wallapop.com/item/camara-go-pro-10-...  20250110
# 32      https://es.wallapop.com/item/gopro-1043835923  20250110
# 33  https://es.wallapop.com/item/gopro-hero-10-107...  20250110
# 34  https://es.wallapop.com/item/gopro-hero-11-bla...  20250110
# 35  https://es.wallapop.com/item/gopro-10-black-10...  20250110
# 36  https://es.wallapop.com/item/gopro-11---extras...  20250110
# 37  https://es.wallapop.com/item/gopro-11-black---...  20250110
# 38  https://es.wallapop.com/item/gopro-hero-black-...  20250110
# 39  https://es.wallapop.com/item/gopro-11-hero-bla...  20250110
# 40  https://es.wallapop.com/item/gooro-hero-10-107...  20250110
# 41  https://es.wallapop.com/item/gopro-11-black-10...  20250110
# 42  https://es.wallapop.com/item/go-pro-hero-10-10...  20250110
# 43  https://es.wallapop.com/item/cambio-panasonic-...  20250110
# 44  https://es.wallapop.com/item/camara-gopro-11-b...  20250110
# 45   https://es.wallapop.com/item/gopro-11-1044882801  20250110
# 46  https://es.wallapop.com/item/go-pro-10-hero-bl...  20250110
# 47  https://es.wallapop.com/item/gopro-11-hero-bla...  20250110
# 48  https://es.wallapop.com/item/gopro-hero-10---a...  20250110
# 49  https://es.wallapop.com/item/gopro-11-kit-1012...  20250110
# 50  https://es.wallapop.com/item/gopro-hero-10-bla...  20250110
# 51  https://es.wallapop.com/item/gopro-hero-11-939...  20250110
# 52    https://es.wallapop.com/item/gopro-10-997314133  20250110
# 53  https://es.wallapop.com/item/gopro-hero-10-bla...  20250110
# 54  https://es.wallapop.com/item/gopro-10-con-acce...  20250110
# 55  https://es.wallapop.com/item/gopro-hero-10-bla...  20250110

# %%
# Asigno columnas MODELO, MEMORIA, COLOR, BATERIA....

# Creo una columna en la que pongo que iphone es (14, 15 o 16..) y que tipo. 
# Gen
# Model
for index in range(len(df)):
    df['gen'] = 'vacio'
    df['modelo'] = 'modelo'

def asignar_gen(nombre):
    if '8' in nombre:
        return '8'
    elif '9' in nombre:
        return '9'
    elif '10' in nombre:
        return '10'
    elif '11' in nombre:
        return '11'
    elif '12' in nombre:
        return '12'
    elif '13' in nombre:
        return '13'
    elif '14' in nombre:
        return '14'
    return "n/a"

# Función para asignar el valor de la columna "modelo"
def asignar_modelo(nombre):
    if 'pro max' in nombre.lower():
        return 'pro max'
    elif 'pro' in nombre.lower():
        return 'pro'
    elif 'plus' in nombre.lower():
        return 'plus'
    else:
        return 'basic'

def asignar_memoria(nombre):
    if '128' in nombre.lower():
        return '128'
    elif '256' in nombre.lower():
        return '256'
    elif '512' in nombre.lower():
        return '512'
    elif '1tb' in nombre.lower():
        return '1tb'
    else:
        return 'n/a'
colores_iphones = ["Púrpura", "Verde", "Blanco", "Azul", "Negro", "Rojo", "Grafito", "Plata", "Oro", "Morado", "titanio", "Ultramarino", 'rojo', 'azul', 'negro', 'blanco', 'verde', 'amarillo', 'rosado', 'rosa', 'gris', 'morado', 'naranja']
# Imprimir todos los colores
def tiene_color(nombre):
    return any(color in nombre.lower() for color in colores_iphones)
def tiene_emojis(nombre):
    return bool(re.search(r'[^\w\s,]', nombre))  # Busca caracteres no alfanuméricos que son emojis
def tiene_vendo(nombre):
    return 'vendo' in nombre.lower()
def tiene_revisado(nombre):
    return 'revisado' in nombre.lower()
    
# Función para asignar el valor de la columna "bateria"
def asignar_bateria(nombre):
    # Buscar números entre 80 y 100 en el nombre
    bateria = re.findall(r'\b([8-9][0-9]|100)\b', nombre)
    if bateria:
        return int(bateria[0])  # Retorna el primer número que encuentra
    return "n/a"

# Aplicar las funciones al DataFrame
df['gen'] = df['nombre'].apply(asignar_gen)
# df['mod'] = df['nombre'].apply(asignar_modelo)
# df['memoria'] = df['nombre'].apply(asignar_memoria)
# df['bateria'] = df['nombre'].apply(asignar_bateria)
orden_columnas = ['id','fecha', 'gen', 'precio', 'estado', 'nombre', 'scrap_locat' , 'dist_scrap_locat',
    'reservado', 'url']
df = df[orden_columnas]
df
# Out:
#             id     fecha gen  precio          estado  \
# 0   1052099071  20250110   9  259,95            good
# 1   1072590194  20250110  12  370,00  as_good_as_new
# 2   1079605964  20250110  12  350,00            good
# 3   1080471539  20250110  12  300,00             new
# 4   1083902061  20250110  11  350,00             new
# 5   1085625687  20250110  10  400,00            good
# 6   1086469969  20250110  11  200,00  as_good_as_new
# 7   1086866366  20250110  10  250,00             new
# 8   1086977927  20250110  10  300,00  as_good_as_new
# 9   1050597462  20250110  12  300,00  as_good_as_new
# 10  1078061746  20250110   9  259,95            good
# 11  1078754814  20250110  10  300,00             new
# 12  1079697974  20250110  11  280,00             new
# 13  1081465646  20250110  12  400,00             new
# 14  1083654200  20250110  11  260,00  as_good_as_new
# 15  1083963942  20250110  10  190,00  as_good_as_new
# 16  1050151212  20250110  12  350,00             new
# 17  1051932652  20250110  11  315,00             new
# 18  1055352107  20250110  11  360,00            good
# 19  1066722758  20250110  12  375,00  as_good_as_new
# 20  1073821636  20250110  10  185,00  as_good_as_new
# 21  1079776254  20250110  10  195,00             new
# 22  1082701930  20250110  11  250,00  as_good_as_new
# 23  1028421251  20250110  12  499,00  as_good_as_new
# 24  1061806929  20250110  11  370,00             new
# 25  1071803247  20250110  10  280,00             new
# 26  1078290389  20250110  10  229,00  as_good_as_new
# 27  1079406835  20250110  11  220,00  as_good_as_new
# 28  1047653797  20250110  12  480,00  as_good_as_new
# 29  1073503955  20250110  10  250,00  as_good_as_new
# 30  1080359690  20250110  11  220,00  as_good_as_new
# 31  1080565222  20250110  10  400,00             new
# 32  1043835923  20250110  10  305,00             new
# 33  1073377586  20250110  10  230,00  as_good_as_new
# 34  1074168225  20250110  11  450,00  as_good_as_new
# 35  1069932964  20250110  10  170,00  as_good_as_new
# 36  1070264638  20250110  11  315,00  as_good_as_new
# 37  1065739896  20250110  11  300,00  as_good_as_new
# 38  1075419904  20250110  10  150,00  as_good_as_new
# 39  1058245981  20250110  11  295,00  as_good_as_new
# 40  1071003713  20250110  10  200,00  as_good_as_new
# 41  1049932839  20250110  11  290,00  as_good_as_new
# 42  1075203306  20250110  10  225,00  as_good_as_new
# 43  1051674571  20250110  10  250,00  as_good_as_new
# 44  1058979498  20250110  11  350,00  as_good_as_new
# 45  1044882801  20250110  11  350,00  as_good_as_new
# 46  1073520820  20250110  10  300,00  as_good_as_new
# 47  1041397524  20250110  11  240,00  as_good_as_new
# 48  1048036050  20250110  10  240,00  as_good_as_new
# 49  1012043733  20250110  11  340,00  as_good_as_new
# 50  1037670264  20250110  10  330,00  as_good_as_new
# 51   939826349  20250110  11  320,00  as_good_as_new
# 52   997314133  20250110  10  180,00  as_good_as_new
# 53  1027999409  20250110  10  300,00  as_good_as_new
# 54   936206770  20250110  10  280,00  as_good_as_new
# 55   934696940  20250110  10  280,00  as_good_as_new
#
#                                            nombre scrap_locat  \
# 0         camara go pro hero 11 black 5.3k 191926      madrid
# 1                                        gopro 12      madrid
# 2                                        gopro 12      madrid
# 3                                   gopro hero 12      madrid
# 4                            go pro 11 como nueva      madrid
# 5                             gopro hero 10 black      madrid
# 6                       go pro hero 11 black mini      madrid
# 7                           go pro hero 10 black       madrid
# 8                             gopro hero black 10      madrid
# 9                             gopro hero 12 naked      madrid
# 10        camara go pro hero 11 black 5.3k 197994      madrid
# 11                       kit gopro 10 black nueva      madrid
# 12                    camara go pro hero 11 black      madrid
# 13                    ⚠️gopro hero 12 naked nueva      madrid
# 14                                 gopro hero 11       madrid
# 15                    gopro hero 10 black edition      madrid
# 16                                  gopro hero 12      madrid
# 17                                 gopro 11 black      madrid
# 18                            gopro hero 11 black      madrid
# 19                                     go pro 12       madrid
# 20                                 gopro 10 black      madrid
# 21                      gopro hero 10 black nueva      madrid
# 22             gopro hero 11 black con accesorios      madrid
# 23                   gopro hero 12 mas accesorios      madrid
# 24                    ⚠️gopro hero 11 naked nueva      madrid
# 25                           gopro 10 black nueva      madrid
# 26                           gopro hero 10 black       madrid
# 27                                 gopro 11 mini       madrid
# 28  gopro hero 12 creator pack + mod max lens 2.0      madrid
# 29                                gopro 10 black       madrid
# 30                                  gopro hero 11      madrid
# 31                         camara go pro 10 black      madrid
# 32                                       gopro 10      madrid
# 33                                 gopro hero 10       madrid
# 34               gopro hero 11 black + accesorios      madrid
# 35                                 gopro 10 black      madrid
# 36                   gopro hero black 11 + extras      madrid
# 37                    gopro 11 black + accesorios      madrid
# 38             gopro hero black 10 con su estuche      madrid
# 39                            gopro 11 hero black      madrid
# 40                                  gopro hero 10      madrid
# 41                                 gopro 11 black      madrid
# 42                                 go pro hero 10      madrid
# 43                  cambio panasonic por gopro 10      madrid
# 44                          cámara gopro 11 black      madrid
# 45                                       gopro 11      madrid
# 46                           go pro 10 hero black      madrid
# 47                            gopro 11 hero black      madrid
# 48                     gopro hero 10 + accesorios      madrid
# 49         gopro 11 +volta + media+kit como nuevo      madrid
# 50                           gopro hero 10 black       madrid
# 51                                  gopro hero 11      madrid
# 52                                      gopro 10       madrid
# 53            gopro hero 10 black + pack max lens      madrid
# 54               gopro 10 + accesorios a estrenar      madrid
# 55                            gopro hero 10 black      madrid
#
#     dist_scrap_locat  reservado  \
# 0                 60      False
# 1                 60      False
# 2                 60      False
# 3                 60      False
# 4                 60      False
# 5                 60      False
# 6                 60      False
# 7                 60      False
# 8                 60      False
# 9                 60      False
# 10                60      False
# 11                60      False
# 12                60      False
# 13                60      False
# 14                60      False
# 15                60      False
# 16                60      False
# 17                60      False
# 18                60      False
# 19                60      False
# 20                60      False
# 21                60      False
# 22                60      False
# 23                60      False
# 24                60      False
# 25                60      False
# 26                60      False
# 27                60      False
# 28                60      False
# 29                60      False
# 30                60      False
# 31                60      False
# 32                60      False
# 33                60      False
# 34                60      False
# 35                60      False
# 36                60      False
# 37                60      False
# 38                60      False
# 39                60      False
# 40                60      False
# 41                60      False
# 42                60      False
# 43                60      False
# 44                60      False
# 45                60      False
# 46                60      False
# 47                60      False
# 48                60      False
# 49                60      False
# 50                60      False
# 51                60      False
# 52                60      False
# 53                60      False
# 54                60      False
# 55                60      False
#
#                                                   url
# 0   https://es.wallapop.com/item/camara-go-pro-her...
# 1    https://es.wallapop.com/item/gopro-12-1072590194
# 2    https://es.wallapop.com/item/gopro-12-1079605964
# 3   https://es.wallapop.com/item/gopro-hero-12-108...
# 4   https://es.wallapop.com/item/go-pro-11-como-nu...
# 5   https://es.wallapop.com/item/gopro-hero-10-bla...
# 6   https://es.wallapop.com/item/go-pro-hero-11-bl...
# 7   https://es.wallapop.com/item/go-pro-hero-10-bl...
# 8   https://es.wallapop.com/item/gopro-hero-black-...
# 9   https://es.wallapop.com/item/gopro-hero-12-nak...
# 10  https://es.wallapop.com/item/camara-go-pro-her...
# 11  https://es.wallapop.com/item/kit-gopro-10-blac...
# 12  https://es.wallapop.com/item/camara-go-pro-her...
# 13  https://es.wallapop.com/item/gopro-12-naked-10...
# 14  https://es.wallapop.com/item/gopro-hero-11-108...
# 15  https://es.wallapop.com/item/gopro-hero-10-bla...
# 16  https://es.wallapop.com/item/gopro-hero-12-105...
# 17  https://es.wallapop.com/item/gopro-11-black-10...
# 18  https://es.wallapop.com/item/gopro-hero-11-bla...
# 19  https://es.wallapop.com/item/go-pro-12-1066722758
# 20  https://es.wallapop.com/item/gopro-10-black-10...
# 21  https://es.wallapop.com/item/gopro-hero-10-bla...
# 22  https://es.wallapop.com/item/gopro-hero-11-bla...
# 23  https://es.wallapop.com/item/gopro-hero-12-mas...
# 24  https://es.wallapop.com/item/gopro-hero-11-nak...
# 25  https://es.wallapop.com/item/gopro-10-black-nu...
# 26  https://es.wallapop.com/item/gopro-hero-10-bla...
# 27  https://es.wallapop.com/item/gopro-11-mini-107...
# 28  https://es.wallapop.com/item/full-equip-go-pro...
# 29  https://es.wallapop.com/item/gopro-10-black-10...
# 30  https://es.wallapop.com/item/gopro-hero-11-108...
# 31  https://es.wallapop.com/item/camara-go-pro-10-...
# 32      https://es.wallapop.com/item/gopro-1043835923
# 33  https://es.wallapop.com/item/gopro-hero-10-107...
# 34  https://es.wallapop.com/item/gopro-hero-11-bla...
# 35  https://es.wallapop.com/item/gopro-10-black-10...
# 36  https://es.wallapop.com/item/gopro-11---extras...
# 37  https://es.wallapop.com/item/gopro-11-black---...
# 38  https://es.wallapop.com/item/gopro-hero-black-...
# 39  https://es.wallapop.com/item/gopro-11-hero-bla...
# 40  https://es.wallapop.com/item/gooro-hero-10-107...
# 41  https://es.wallapop.com/item/gopro-11-black-10...
# 42  https://es.wallapop.com/item/go-pro-hero-10-10...
# 43  https://es.wallapop.com/item/cambio-panasonic-...
# 44  https://es.wallapop.com/item/camara-gopro-11-b...
# 45   https://es.wallapop.com/item/gopro-11-1044882801
# 46  https://es.wallapop.com/item/go-pro-10-hero-bl...
# 47  https://es.wallapop.com/item/gopro-11-hero-bla...
# 48  https://es.wallapop.com/item/gopro-hero-10---a...
# 49  https://es.wallapop.com/item/gopro-11-kit-1012...
# 50  https://es.wallapop.com/item/gopro-hero-10-bla...
# 51  https://es.wallapop.com/item/gopro-hero-11-939...
# 52    https://es.wallapop.com/item/gopro-10-997314133
# 53  https://es.wallapop.com/item/gopro-hero-10-bla...
# 54  https://es.wallapop.com/item/gopro-10-con-acce...
# 55  https://es.wallapop.com/item/gopro-hero-10-bla...

# %%
# df['tiene_color'] = df['nombre'].apply(tiene_color)
# df['tiene_emojis'] = df['nombre'].apply(tiene_emojis)
# df['tiene_revisado'] = df['nombre'].apply(tiene_revisado)

# %%
carpeta = "3_feature_engineering"
if not os.path.exists(carpeta):
    os.makedirs(carpeta)
nombre_archivo = f"{carpeta}/gopro_{fecha}.xlsx" # excel ofrece ventajas para abrirlo en tableu. Pero no recuerdo cuales
df = df.reset_index(drop=True) # sin indice
df.to_excel(nombre_archivo, index=False)
#print(nombre_archivo_csv, "creado exitosamente")
