# %% [markdown]
# ## Featuring engineering
# creo variables como, si tiene color, si tiene emojis, si pone "vendo", si pone "revisado"

# %%
import os
import pandas as pd
import re

# %%
carpeta = "2_datos_por_fecha"
fecha = "20241114"

# %%
df = pd.read_csv(carpeta + '/' + fecha + '.csv', index_col=0)

# %%
df
# Out:
#               id     fecha  gen      mod memoria  bateria   precio  \
# 0     1068541305  20241114   16    basic     128      NaN   800,00
# 1     1069277594  20241114   14      pro     NaN      NaN   700,00
# 2     1069385453  20241114   16    basic     NaN      NaN   850,00
# 3     1069408278  20241114   14      pro     NaN      NaN   800,00
# 4     1069426273  20241114   16  pro max     NaN      NaN  1020,00
# ...          ...       ...  ...      ...     ...      ...      ...
# 1453  1064280078  20241114   14     plus     128      NaN   589,00
# 1454  1063248685  20241114   14      pro     NaN      NaN   675,00
# 1455  1063827942  20241114   14  pro max     NaN      NaN   850,00
# 1456  1064909050  20241114   14  pro max     128      NaN   799,00
# 1457  1064897533  20241114   14  pro max     256      NaN   819,00
#
#               estado                         nombre  reservado  \
# 0                new                iphone 16 128gb      False
# 1                new           iphone 14 pro morado      False
# 2     as_good_as_new                      iphone 16      False
# 3               good                  iphone 14 pro      False
# 4               good              iphone 16 pro max      False
# ...              ...                            ...        ...
# 1453  as_good_as_new          iphone 14 plus 128gb       False
# 1454  as_good_as_new                  iphone 14 pro      False
# 1455  as_good_as_new              iphone 14 pro max      False
# 1456  as_good_as_new  iphone 14 pro max 128gb nuevo      False
# 1457  as_good_as_new  iphone 14 pro max 256gb nuevo      False
#
#                                                     url
# 0     https://es.wallapop.com/item/iphone-16-128gb-1...
# 1     https://es.wallapop.com/item/iphone-14-pro-mor...
# 2     https://es.wallapop.com/item/iphone-16-1069385453
# 3     https://es.wallapop.com/item/iphone-14-pro-106...
# 4     https://es.wallapop.com/item/iphone-16-pro-max...
# ...                                                 ...
# 1453  https://es.wallapop.com/item/iphone-14-plus-12...
# 1454  https://es.wallapop.com/item/iphone-14-pro-106...
# 1455  https://es.wallapop.com/item/iphone-14-pro-max...
# 1456  https://es.wallapop.com/item/iphone-14-pro-max...
# 1457  https://es.wallapop.com/item/iphone-14-pro-max...
#
# [1458 rows x 11 columns]

# %%
colores_iphones = ["Púrpura", "Verde", "Blanco", "Azul", "Negro", "Rojo", "Grafito", "Plata", "Oro", "Morado", "titanio", "Ultramarino", 'rojo', 'azul', 'negro', 'blanco', 'verde', 'amarillo', 'rosado', 'rosa', 'gris', 'morado', 'naranja']
# Imprimir todos los colores
def tiene_color(nombre):
    return any(color in nombre.lower() for color in colores_iphones)
def tiene_emojis(nombre):
    return bool(re.search(r'[^\w\s,]', nombre))  # Busca caracteres no alfanuméricos que son emojis
def tiene_vendo(nombre):
    return 'vendo' in nombre.lower()
def tiene_revisado(nombre):
    return 'revisado' in nombre.lower()

df['tiene_color'] = df['nombre'].apply(tiene_color)
df['tiene_emojis'] = df['nombre'].apply(tiene_emojis)
df['tiene_revisado'] = df['nombre'].apply(tiene_revisado)
df
# Out:
#               id     fecha  gen      mod memoria  bateria   precio  \
# 0     1068541305  20241114   16    basic     128      NaN   800,00
# 1     1069277594  20241114   14      pro     NaN      NaN   700,00
# 2     1069385453  20241114   16    basic     NaN      NaN   850,00
# 3     1069408278  20241114   14      pro     NaN      NaN   800,00
# 4     1069426273  20241114   16  pro max     NaN      NaN  1020,00
# ...          ...       ...  ...      ...     ...      ...      ...
# 1453  1064280078  20241114   14     plus     128      NaN   589,00
# 1454  1063248685  20241114   14      pro     NaN      NaN   675,00
# 1455  1063827942  20241114   14  pro max     NaN      NaN   850,00
# 1456  1064909050  20241114   14  pro max     128      NaN   799,00
# 1457  1064897533  20241114   14  pro max     256      NaN   819,00
#
#               estado                         nombre  reservado  \
# 0                new                iphone 16 128gb      False
# 1                new           iphone 14 pro morado      False
# 2     as_good_as_new                      iphone 16      False
# 3               good                  iphone 14 pro      False
# 4               good              iphone 16 pro max      False
# ...              ...                            ...        ...
# 1453  as_good_as_new          iphone 14 plus 128gb       False
# 1454  as_good_as_new                  iphone 14 pro      False
# 1455  as_good_as_new              iphone 14 pro max      False
# 1456  as_good_as_new  iphone 14 pro max 128gb nuevo      False
# 1457  as_good_as_new  iphone 14 pro max 256gb nuevo      False
#
#                                                     url  tiene_color  \
# 0     https://es.wallapop.com/item/iphone-16-128gb-1...        False
# 1     https://es.wallapop.com/item/iphone-14-pro-mor...         True
# 2     https://es.wallapop.com/item/iphone-16-1069385453        False
# 3     https://es.wallapop.com/item/iphone-14-pro-106...        False
# 4     https://es.wallapop.com/item/iphone-16-pro-max...        False
# ...                                                 ...          ...
# 1453  https://es.wallapop.com/item/iphone-14-plus-12...        False
# 1454  https://es.wallapop.com/item/iphone-14-pro-106...        False
# 1455  https://es.wallapop.com/item/iphone-14-pro-max...        False
# 1456  https://es.wallapop.com/item/iphone-14-pro-max...        False
# 1457  https://es.wallapop.com/item/iphone-14-pro-max...        False
#
#       tiene_emojis  tiene_revisado
# 0            False           False
# 1            False           False
# 2            False           False
# 3            False           False
# 4            False           False
# ...            ...             ...
# 1453         False           False
# 1454         False           False
# 1455         False           False
# 1456         False           False
# 1457         False           False
#
# [1458 rows x 14 columns]

# %%
carpeta = "3_datos_finales"
if not os.path.exists(carpeta):
    os.makedirs(carpeta)
nombre_archivo = f"{carpeta}/{fecha}.xlsx"
df = df.reset_index(drop=True) # sin indice
df.to_excel(nombre_archivo, index=False)
#print(nombre_archivo_csv, "creado exitosamente")
