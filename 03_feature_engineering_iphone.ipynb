# %% [markdown]
# ## Featuring engineering
# creo variables como, si tiene color, si tiene emojis, si pone "vendo", si pone "revisado"

# %%
import os
import pandas as pd
import re
from datetime import datetime

# %%
carpeta = "2_datos_por_fecha"
fecha = datetime.now().strftime("%Y%m%d")
fecha = "20241114"

# %%
df = pd.read_csv(carpeta + '/' + "iphone_" + fecha + '.csv', index_col=0)

# %%
df
# Out:
#               id     fecha   gen      mod memoria  bateria   precio  \
# 0     1068541305  20241114  16.0    basic     128      NaN   800,00
# 1     1069277594  20241114  14.0      pro     NaN      NaN   700,00
# 2     1069385453  20241114  16.0    basic     NaN      NaN   850,00
# 3     1069408278  20241114  14.0      pro     NaN      NaN   800,00
# 4     1069426273  20241114  16.0  pro max     NaN      NaN  1020,00
# ...          ...       ...   ...      ...     ...      ...      ...
# 1526  1064280078  20241114  14.0     plus     128      NaN   589,00
# 1527  1063248685  20241114  14.0      pro     NaN      NaN   675,00
# 1528  1063827942  20241114  14.0  pro max     NaN      NaN   850,00
# 1529  1064909050  20241114  14.0  pro max     128      NaN   799,00
# 1530  1064897533  20241114  14.0  pro max     256      NaN   819,00
#
#               estado                         nombre scrap_locat  \
# 0                new                iphone 16 128gb      madrid
# 1                new           iphone 14 pro morado      madrid
# 2     as_good_as_new                      iphone 16      madrid
# 3               good                  iphone 14 pro      madrid
# 4               good              iphone 16 pro max      madrid
# ...              ...                            ...         ...
# 1526  as_good_as_new          iphone 14 plus 128gb       madrid
# 1527  as_good_as_new                  iphone 14 pro      madrid
# 1528  as_good_as_new              iphone 14 pro max      madrid
# 1529  as_good_as_new  iphone 14 pro max 128gb nuevo      madrid
# 1530  as_good_as_new  iphone 14 pro max 256gb nuevo      madrid
#
#       dist_scrap_locat  reservado  \
# 0                   60      False
# 1                   60      False
# 2                   60      False
# 3                   60      False
# 4                   60      False
# ...                ...        ...
# 1526                60      False
# 1527                60      False
# 1528                60      False
# 1529                60      False
# 1530                60      False
#
#                                                     url
# 0     https://es.wallapop.com/item/iphone-16-128gb-1...
# 1     https://es.wallapop.com/item/iphone-14-pro-mor...
# 2     https://es.wallapop.com/item/iphone-16-1069385453
# 3     https://es.wallapop.com/item/iphone-14-pro-106...
# 4     https://es.wallapop.com/item/iphone-16-pro-max...
# ...                                                 ...
# 1526  https://es.wallapop.com/item/iphone-14-plus-12...
# 1527  https://es.wallapop.com/item/iphone-14-pro-106...
# 1528  https://es.wallapop.com/item/iphone-14-pro-max...
# 1529  https://es.wallapop.com/item/iphone-14-pro-max...
# 1530  https://es.wallapop.com/item/iphone-14-pro-max...
#
# [1531 rows x 13 columns]

# %%
# Asigno columnas MODELO, MEMORIA, COLOR, BATERIA....

# Creo una columna en la que pongo que iphone es (14, 15 o 16..) y que tipo. 
# Gen
# Model
for index in range(len(df)):
    df['gen'] = 'vacio'
    df['modelo'] = 'modelo'

def asignar_gen(nombre):
    if '14' in nombre:
        return '14'
    elif '15' in nombre:
        return '15'
    elif '16' in nombre:
        return '16'
    return "n/a"

# Función para asignar el valor de la columna "modelo"
def asignar_modelo(nombre):
    if 'pro max' in nombre.lower():
        return 'pro max'
    elif 'pro' in nombre.lower():
        return 'pro'
    elif 'plus' in nombre.lower():
        return 'plus'
    else:
        return 'basic'

def asignar_memoria(nombre):
    if '128' in nombre.lower():
        return '128'
    elif '256' in nombre.lower():
        return '256'
    elif '512' in nombre.lower():
        return '512'
    elif '1tb' in nombre.lower():
        return '1tb'
    else:
        return 'n/a'

# Función para asignar el valor de la columna "bateria"
def asignar_bateria(nombre):
    # Buscar números entre 80 y 100 en el nombre
    bateria = re.findall(r'\b([8-9][0-9]|100)\b', nombre)
    if bateria:
        return int(bateria[0])  # Retorna el primer número que encuentra
    return "n/a"

# Aplicar las funciones al DataFrame
df['gen'] = df['nombre'].apply(asignar_gen)
df['mod'] = df['nombre'].apply(asignar_modelo)
df['memoria'] = df['nombre'].apply(asignar_memoria)
df['bateria'] = df['nombre'].apply(asignar_bateria)
orden_columnas = ['id','fecha', 'gen', 'mod', 'memoria', 'bateria','precio', 'estado', 'nombre', 'scrap_locat' , 'dist_scrap_locat',
    'reservado', 'url']
df = df[orden_columnas]
df
# Out:
#               id     fecha gen      mod memoria bateria   precio  \
# 0     1068541305  20241114  16    basic     128     n/a   800,00
# 1     1069277594  20241114  14      pro     n/a     n/a   700,00
# 2     1069385453  20241114  16    basic     n/a     n/a   850,00
# 3     1069408278  20241114  14      pro     n/a     n/a   800,00
# 4     1069426273  20241114  16  pro max     n/a     n/a  1020,00
# ...          ...       ...  ..      ...     ...     ...      ...
# 1526  1064280078  20241114  14     plus     128     n/a   589,00
# 1527  1063248685  20241114  14      pro     n/a     n/a   675,00
# 1528  1063827942  20241114  14  pro max     n/a     n/a   850,00
# 1529  1064909050  20241114  14  pro max     128     n/a   799,00
# 1530  1064897533  20241114  14  pro max     256     n/a   819,00
#
#               estado                         nombre scrap_locat  \
# 0                new                iphone 16 128gb      madrid
# 1                new           iphone 14 pro morado      madrid
# 2     as_good_as_new                      iphone 16      madrid
# 3               good                  iphone 14 pro      madrid
# 4               good              iphone 16 pro max      madrid
# ...              ...                            ...         ...
# 1526  as_good_as_new          iphone 14 plus 128gb       madrid
# 1527  as_good_as_new                  iphone 14 pro      madrid
# 1528  as_good_as_new              iphone 14 pro max      madrid
# 1529  as_good_as_new  iphone 14 pro max 128gb nuevo      madrid
# 1530  as_good_as_new  iphone 14 pro max 256gb nuevo      madrid
#
#       dist_scrap_locat  reservado  \
# 0                   60      False
# 1                   60      False
# 2                   60      False
# 3                   60      False
# 4                   60      False
# ...                ...        ...
# 1526                60      False
# 1527                60      False
# 1528                60      False
# 1529                60      False
# 1530                60      False
#
#                                                     url
# 0     https://es.wallapop.com/item/iphone-16-128gb-1...
# 1     https://es.wallapop.com/item/iphone-14-pro-mor...
# 2     https://es.wallapop.com/item/iphone-16-1069385453
# 3     https://es.wallapop.com/item/iphone-14-pro-106...
# 4     https://es.wallapop.com/item/iphone-16-pro-max...
# ...                                                 ...
# 1526  https://es.wallapop.com/item/iphone-14-plus-12...
# 1527  https://es.wallapop.com/item/iphone-14-pro-106...
# 1528  https://es.wallapop.com/item/iphone-14-pro-max...
# 1529  https://es.wallapop.com/item/iphone-14-pro-max...
# 1530  https://es.wallapop.com/item/iphone-14-pro-max...
#
# [1531 rows x 13 columns]

# %%
colores_iphones = ["Púrpura", "Verde", "Blanco", "Azul", "Negro", "Rojo", "Grafito", "Plata", "Oro", "Morado", "titanio", "Ultramarino", 'rojo', 'azul', 'negro', 'blanco', 'verde', 'amarillo', 'rosado', 'rosa', 'gris', 'morado', 'naranja']
# Imprimir todos los colores
def tiene_color(nombre):
    return any(color in nombre.lower() for color in colores_iphones)
def tiene_emojis(nombre):
    return bool(re.search(r'[^\w\s,]', nombre))  # Busca caracteres no alfanuméricos que son emojis
def tiene_vendo(nombre):
    return 'vendo' in nombre.lower()
def tiene_revisado(nombre):
    return 'revisado' in nombre.lower()

df['tiene_color'] = df['nombre'].apply(tiene_color)
df['tiene_emojis'] = df['nombre'].apply(tiene_emojis)
df['tiene_revisado'] = df['nombre'].apply(tiene_revisado)
df
# Out:
#               id     fecha gen      mod memoria bateria   precio  \
# 0     1068541305  20241114  16    basic     128     n/a   800,00
# 1     1069277594  20241114  14      pro     n/a     n/a   700,00
# 2     1069385453  20241114  16    basic     n/a     n/a   850,00
# 3     1069408278  20241114  14      pro     n/a     n/a   800,00
# 4     1069426273  20241114  16  pro max     n/a     n/a  1020,00
# ...          ...       ...  ..      ...     ...     ...      ...
# 1526  1064280078  20241114  14     plus     128     n/a   589,00
# 1527  1063248685  20241114  14      pro     n/a     n/a   675,00
# 1528  1063827942  20241114  14  pro max     n/a     n/a   850,00
# 1529  1064909050  20241114  14  pro max     128     n/a   799,00
# 1530  1064897533  20241114  14  pro max     256     n/a   819,00
#
#               estado                         nombre scrap_locat  \
# 0                new                iphone 16 128gb      madrid
# 1                new           iphone 14 pro morado      madrid
# 2     as_good_as_new                      iphone 16      madrid
# 3               good                  iphone 14 pro      madrid
# 4               good              iphone 16 pro max      madrid
# ...              ...                            ...         ...
# 1526  as_good_as_new          iphone 14 plus 128gb       madrid
# 1527  as_good_as_new                  iphone 14 pro      madrid
# 1528  as_good_as_new              iphone 14 pro max      madrid
# 1529  as_good_as_new  iphone 14 pro max 128gb nuevo      madrid
# 1530  as_good_as_new  iphone 14 pro max 256gb nuevo      madrid
#
#       dist_scrap_locat  reservado  \
# 0                   60      False
# 1                   60      False
# 2                   60      False
# 3                   60      False
# 4                   60      False
# ...                ...        ...
# 1526                60      False
# 1527                60      False
# 1528                60      False
# 1529                60      False
# 1530                60      False
#
#                                                     url  tiene_color  \
# 0     https://es.wallapop.com/item/iphone-16-128gb-1...        False
# 1     https://es.wallapop.com/item/iphone-14-pro-mor...         True
# 2     https://es.wallapop.com/item/iphone-16-1069385453        False
# 3     https://es.wallapop.com/item/iphone-14-pro-106...        False
# 4     https://es.wallapop.com/item/iphone-16-pro-max...        False
# ...                                                 ...          ...
# 1526  https://es.wallapop.com/item/iphone-14-plus-12...        False
# 1527  https://es.wallapop.com/item/iphone-14-pro-106...        False
# 1528  https://es.wallapop.com/item/iphone-14-pro-max...        False
# 1529  https://es.wallapop.com/item/iphone-14-pro-max...        False
# 1530  https://es.wallapop.com/item/iphone-14-pro-max...        False
#
#       tiene_emojis  tiene_revisado
# 0            False           False
# 1            False           False
# 2            False           False
# 3            False           False
# 4            False           False
# ...            ...             ...
# 1526         False           False
# 1527         False           False
# 1528         False           False
# 1529         False           False
# 1530         False           False
#
# [1531 rows x 16 columns]

# %%
carpeta = "3_feature_engineering"
if not os.path.exists(carpeta):
    os.makedirs(carpeta)
nombre_archivo = f"{carpeta}/iphone_{fecha}.xlsx" # excel ofrece ventajas para abrirlo en tableu. Pero no recuerdo cuales
df = df.reset_index(drop=True) # sin indice
df.to_excel(nombre_archivo, index=False)
#print(nombre_archivo_csv, "creado exitosamente")
