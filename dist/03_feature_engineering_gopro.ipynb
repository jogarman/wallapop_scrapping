# %% [markdown]
# ## Featuring engineering
# obtengo variables como el modelo de la gopro

# %%
import os
import pandas as pd
import re
from datetime import datetime

# %%
carpeta = "../2_datos_por_fecha"
fecha = datetime.now().strftime("%Y%m%d")
#fecha = "20250102"

# %%
df = pd.read_csv(carpeta + '/' + "gopro_" + fecha + '.csv', index_col=0)

# %%
df
# Out:
#             id                                             nombre  precio  \
# 0   1099048358                               go pro black hero 10  400,00
# 1   1090787536                                           gopro 10  248,00
# 2   1091568974                                     gopro 10 black  249,00
# 3   1094003898                                gopro hero 10 black  310,00
# 4   1091711762                   gopro hero 10 black y accesorios  240,00
# 5   1086977927                                gopro hero black 10  200,00
# 6   1069932964                                     gopro 10 black  160,00
# 7   1071003713                                      gopro hero 10  200,00
# 8   1051674571                      cambio panasonic por gopro 10  250,00
# 9   1048036050                         gopro hero 10 + accesorios  230,00
# 10  1037670264                               gopro hero 10 black   330,00
# 11  1006123008                                           gopro 10  200,00
# 12   997314133                                          gopro 10   180,00
# 13  1027999409                gopro hero 10 black + pack max lens  300,00
# 14   936206770            gopro hero 10 con accesorios a estrenar  260,00
# 15   934696940                                gopro hero 10 black  280,00
# 16  1100307962                                     gopro 10 black  200,00
# 17  1085625687                                gopro hero 10 black  375,00
# 18  1096049607                gopro hero 10 black con accesorios   350,00
# 19  1086866366                              go pro hero 10 black   250,00
# 20  1080565222                             camara go pro 10 black  350,00
# 21  1030106635                                      gopro hero 10  270,00
# 22  1094638512                                    gopro 11 black   330,00
# 23  1094487184                                      gopro hero 11  250,00
# 24  1092024308                camara ultracompacta gopro 11 black  289,00
# 25  1092221554                      gopro hero 11 sin apenas uso.  280,00
# 26  1092505387               gopro hero 11 black  baterias enduro  340,00
# 27  1080359690                                      gopro hero 11  220,00
# 28  1074168225                   gopro hero 11 black + accesorios  400,00
# 29  1070264638                       gopro hero black 11 + extras  315,00
# 30  1065739896                        gopro 11 black + accesorios  300,00
# 31  1058245981                                gopro 11 hero black  295,00
# 32  1049932839                                     gopro 11 black  290,00
# 33  1058979498                              cámara gopro 11 black  350,00
# 34  1044882801                                           gopro 11  350,00
# 35  1041397524                                gopro 11 hero black  240,00
# 36  1012043733             gopro 11 +volta + media+kit como nuevo  340,00
# 37  1055352107                                gopro hero 11 black  360,00
# 38  1099417392                                      gopro hero 11  250,00
# 39  1094909743                               go pro hero 11 black  290,00
# 40  1094903053                              go pro hero 11 black   270,00
# 41  1083902061                               go pro 11 como nueva  350,00
# 42  1061806929                        ⚠️gopro hero 11 naked nueva  360,00
# 43  1099559245                                gopro hero 12 black  300,00
# 44  1097081705                               gopro hero 12 black   320,00
# 45  1098650360                               go pro hero 12 black  350,00
# 46  1072590194                                           gopro 12  310,00
# 47  1050597462                                gopro hero 12 naked  300,00
# 48  1066722758                                         go pro 12   325,00
# 49  1098125239  camara gopro hero 12 black + kit accesorios 20...  299,95
# 50  1094196062                                gopro hero 12 black  280,00
# 51  1081465646                        ⚠️gopro hero 12 naked nueva  390,00
# 52  1050151212                                      gopro hero 12  350,00
# 53  1100412627                                gopro 13 y sd 128gb  299,00
# 54  1094367879                                     gopro 13 black  350,00
#
#             estado scrap_locat  dist_scrap_locat  reservado  \
# 0   as_good_as_new      madrid                60      False
# 1   as_good_as_new      madrid                60      False
# 2   as_good_as_new      madrid                60      False
# 3   as_good_as_new      madrid                60      False
# 4   as_good_as_new      madrid                60      False
# 5   as_good_as_new      madrid                60      False
# 6   as_good_as_new      madrid                60      False
# 7   as_good_as_new      madrid                60      False
# 8   as_good_as_new      madrid                60      False
# 9   as_good_as_new      madrid                60      False
# 10  as_good_as_new      madrid                60      False
# 11  as_good_as_new      madrid                60      False
# 12  as_good_as_new      madrid                60      False
# 13  as_good_as_new      madrid                60      False
# 14  as_good_as_new      madrid                60      False
# 15  as_good_as_new      madrid                60      False
# 16            good      madrid                60      False
# 17            good      madrid                60      False
# 18             new      madrid                60      False
# 19             new      madrid                60      False
# 20             new      madrid                60      False
# 21             new      madrid                60      False
# 22  as_good_as_new      madrid                60      False
# 23  as_good_as_new      madrid                60      False
# 24  as_good_as_new      madrid                60      False
# 25  as_good_as_new      madrid                60      False
# 26  as_good_as_new      madrid                60      False
# 27  as_good_as_new      madrid                60      False
# 28  as_good_as_new      madrid                60      False
# 29  as_good_as_new      madrid                60      False
# 30  as_good_as_new      madrid                60      False
# 31  as_good_as_new      madrid                60      False
# 32  as_good_as_new      madrid                60      False
# 33  as_good_as_new      madrid                60      False
# 34  as_good_as_new      madrid                60      False
# 35  as_good_as_new      madrid                60      False
# 36  as_good_as_new      madrid                60      False
# 37            good      madrid                60      False
# 38             new      madrid                60      False
# 39             new      madrid                60      False
# 40             new      madrid                60      False
# 41             new      madrid                60      False
# 42             new      madrid                60      False
# 43  as_good_as_new      madrid                60      False
# 44  as_good_as_new      madrid                60      False
# 45  as_good_as_new      madrid                60      False
# 46  as_good_as_new      madrid                60      False
# 47  as_good_as_new      madrid                60      False
# 48  as_good_as_new      madrid                60      False
# 49            good      madrid                60      False
# 50             new      madrid                60      False
# 51             new      madrid                60      False
# 52             new      madrid                60      False
# 53             new      madrid                60      False
# 54             new      madrid                60      False
#
#                                                   url     fecha
# 0   https://es.wallapop.com/item/go-pro-black-hero...  20250211
# 1    https://es.wallapop.com/item/gopro-10-1090787536  20250211
# 2   https://es.wallapop.com/item/gopro-10-black-10...  20250211
# 3   https://es.wallapop.com/item/gopro-hero-10-bla...  20250211
# 4   https://es.wallapop.com/item/gopro-hero-10-bla...  20250211
# 5   https://es.wallapop.com/item/gopro-hero-black-...  20250211
# 6   https://es.wallapop.com/item/gopro-10-black-10...  20250211
# 7   https://es.wallapop.com/item/gooro-hero-10-107...  20250211
# 8   https://es.wallapop.com/item/cambio-panasonic-...  20250211
# 9   https://es.wallapop.com/item/gopro-hero-10---a...  20250211
# 10  https://es.wallapop.com/item/gopro-hero-10-bla...  20250211
# 11   https://es.wallapop.com/item/gopro-10-1006123008  20250211
# 12    https://es.wallapop.com/item/gopro-10-997314133  20250211
# 13  https://es.wallapop.com/item/gopro-hero-10-bla...  20250211
# 14  https://es.wallapop.com/item/gopro-10-con-acce...  20250211
# 15  https://es.wallapop.com/item/gopro-hero-10-bla...  20250211
# 16  https://es.wallapop.com/item/gopro-10-black-11...  20250211
# 17  https://es.wallapop.com/item/gopro-hero-10-bla...  20250211
# 18  https://es.wallapop.com/item/gopro-hero-10-bla...  20250211
# 19  https://es.wallapop.com/item/go-pro-hero-10-bl...  20250211
# 20  https://es.wallapop.com/item/camara-go-pro-10-...  20250211
# 21  https://es.wallapop.com/item/gopro-hero-10-103...  20250211
# 22  https://es.wallapop.com/item/gopro-11-black-10...  20250211
# 23  https://es.wallapop.com/item/gopro-hero-11-109...  20250211
# 24  https://es.wallapop.com/item/camara-ultracompa...  20250211
# 25  https://es.wallapop.com/item/gopro-hero-11-sin...  20250211
# 26  https://es.wallapop.com/item/gopro-hero-11-bla...  20250211
# 27  https://es.wallapop.com/item/gopro-hero-11-108...  20250211
# 28  https://es.wallapop.com/item/gopro-hero-11-bla...  20250211
# 29  https://es.wallapop.com/item/gopro-11---extras...  20250211
# 30  https://es.wallapop.com/item/gopro-11-black---...  20250211
# 31  https://es.wallapop.com/item/gopro-11-hero-bla...  20250211
# 32  https://es.wallapop.com/item/gopro-11-black-10...  20250211
# 33  https://es.wallapop.com/item/camara-gopro-11-b...  20250211
# 34   https://es.wallapop.com/item/gopro-11-1044882801  20250211
# 35  https://es.wallapop.com/item/gopro-11-hero-bla...  20250211
# 36  https://es.wallapop.com/item/gopro-11-kit-1012...  20250211
# 37  https://es.wallapop.com/item/gopro-hero-11-bla...  20250211
# 38  https://es.wallapop.com/item/gopro-hero-11-109...  20250211
# 39  https://es.wallapop.com/item/go-pro-hero-11-bl...  20250211
# 40  https://es.wallapop.com/item/go-pro-hero-11-bl...  20250211
# 41  https://es.wallapop.com/item/go-pro-11-como-nu...  20250211
# 42  https://es.wallapop.com/item/gopro-hero-11-nak...  20250211
# 43  https://es.wallapop.com/item/gopro-hero-12-bla...  20250211
# 44  https://es.wallapop.com/item/gopro-hero-12-bla...  20250211
# 45  https://es.wallapop.com/item/go-pro-hero-12-bl...  20250211
# 46   https://es.wallapop.com/item/gopro-12-1072590194  20250211
# 47  https://es.wallapop.com/item/gopro-hero-12-nak...  20250211
# 48  https://es.wallapop.com/item/go-pro-12-1066722758  20250211
# 49  https://es.wallapop.com/item/camara-gopro-hero...  20250211
# 50  https://es.wallapop.com/item/gopro-hero-12-bla...  20250211
# 51  https://es.wallapop.com/item/gopro-12-naked-10...  20250211
# 52  https://es.wallapop.com/item/gopro-hero-12-105...  20250211
# 53  https://es.wallapop.com/item/gopro-13-y-sd-128...  20250211
# 54  https://es.wallapop.com/item/gopro-13-black-10...  20250211

# %%
# Asigno columnas MODELO, MEMORIA, COLOR, BATERIA....

# Creo una columna en la que pongo que iphone es (14, 15 o 16..) y que tipo. 
# Gen
# Model
for index in range(len(df)):
    df['gen'] = 'vacio'
    df['modelo'] = 'modelo'

def asignar_gen(nombre):
    if '8' in nombre:
        return '8'
    elif '9' in nombre:
        return '9'
    elif '10' in nombre:
        return '10'
    elif '11' in nombre:
        return '11'
    elif '12' in nombre:
        return '12'
    elif '13' in nombre:
        return '13'
    elif '14' in nombre:
        return '14'
    return "n/a"

# Función para asignar el valor de la columna "modelo"
def asignar_modelo(nombre):
    if 'pro max' in nombre.lower():
        return 'pro max'
    elif 'pro' in nombre.lower():
        return 'pro'
    elif 'plus' in nombre.lower():
        return 'plus'
    else:
        return 'basic'

def asignar_memoria(nombre):
    if '128' in nombre.lower():
        return '128'
    elif '256' in nombre.lower():
        return '256'
    elif '512' in nombre.lower():
        return '512'
    elif '1tb' in nombre.lower():
        return '1tb'
    else:
        return 'n/a'
colores_iphones = ["Púrpura", "Verde", "Blanco", "Azul", "Negro", "Rojo", "Grafito", "Plata", "Oro", "Morado", "titanio", "Ultramarino", 'rojo', 'azul', 'negro', 'blanco', 'verde', 'amarillo', 'rosado', 'rosa', 'gris', 'morado', 'naranja']
# Imprimir todos los colores
def tiene_color(nombre):
    return any(color in nombre.lower() for color in colores_iphones)
def tiene_emojis(nombre):
    return bool(re.search(r'[^\w\s,]', nombre))  # Busca caracteres no alfanuméricos que son emojis
def tiene_vendo(nombre):
    return 'vendo' in nombre.lower()
def tiene_revisado(nombre):
    return 'revisado' in nombre.lower()
    
# Función para asignar el valor de la columna "bateria"
def asignar_bateria(nombre):
    # Buscar números entre 80 y 100 en el nombre
    bateria = re.findall(r'\b([8-9][0-9]|100)\b', nombre)
    if bateria:
        return int(bateria[0])  # Retorna el primer número que encuentra
    return "n/a"

# Aplicar las funciones al DataFrame
df['gen'] = df['nombre'].apply(asignar_gen)
# df['mod'] = df['nombre'].apply(asignar_modelo)
# df['memoria'] = df['nombre'].apply(asignar_memoria)
# df['bateria'] = df['nombre'].apply(asignar_bateria)
orden_columnas = ['id','fecha', 'gen', 'precio', 'estado', 'nombre', 'scrap_locat' , 'dist_scrap_locat',
    'reservado', 'url']
df = df[orden_columnas]
df
# Out:
#             id     fecha gen  precio          estado  \
# 0   1099048358  20250211  10  400,00  as_good_as_new
# 1   1090787536  20250211  10  248,00  as_good_as_new
# 2   1091568974  20250211  10  249,00  as_good_as_new
# 3   1094003898  20250211  10  310,00  as_good_as_new
# 4   1091711762  20250211  10  240,00  as_good_as_new
# 5   1086977927  20250211  10  200,00  as_good_as_new
# 6   1069932964  20250211  10  160,00  as_good_as_new
# 7   1071003713  20250211  10  200,00  as_good_as_new
# 8   1051674571  20250211  10  250,00  as_good_as_new
# 9   1048036050  20250211  10  230,00  as_good_as_new
# 10  1037670264  20250211  10  330,00  as_good_as_new
# 11  1006123008  20250211  10  200,00  as_good_as_new
# 12   997314133  20250211  10  180,00  as_good_as_new
# 13  1027999409  20250211  10  300,00  as_good_as_new
# 14   936206770  20250211  10  260,00  as_good_as_new
# 15   934696940  20250211  10  280,00  as_good_as_new
# 16  1100307962  20250211  10  200,00            good
# 17  1085625687  20250211  10  375,00            good
# 18  1096049607  20250211  10  350,00             new
# 19  1086866366  20250211  10  250,00             new
# 20  1080565222  20250211  10  350,00             new
# 21  1030106635  20250211  10  270,00             new
# 22  1094638512  20250211  11  330,00  as_good_as_new
# 23  1094487184  20250211  11  250,00  as_good_as_new
# 24  1092024308  20250211  11  289,00  as_good_as_new
# 25  1092221554  20250211  11  280,00  as_good_as_new
# 26  1092505387  20250211  11  340,00  as_good_as_new
# 27  1080359690  20250211  11  220,00  as_good_as_new
# 28  1074168225  20250211  11  400,00  as_good_as_new
# 29  1070264638  20250211  11  315,00  as_good_as_new
# 30  1065739896  20250211  11  300,00  as_good_as_new
# 31  1058245981  20250211  11  295,00  as_good_as_new
# 32  1049932839  20250211  11  290,00  as_good_as_new
# 33  1058979498  20250211  11  350,00  as_good_as_new
# 34  1044882801  20250211  11  350,00  as_good_as_new
# 35  1041397524  20250211  11  240,00  as_good_as_new
# 36  1012043733  20250211  11  340,00  as_good_as_new
# 37  1055352107  20250211  11  360,00            good
# 38  1099417392  20250211  11  250,00             new
# 39  1094909743  20250211  11  290,00             new
# 40  1094903053  20250211  11  270,00             new
# 41  1083902061  20250211  11  350,00             new
# 42  1061806929  20250211  11  360,00             new
# 43  1099559245  20250211  12  300,00  as_good_as_new
# 44  1097081705  20250211  12  320,00  as_good_as_new
# 45  1098650360  20250211  12  350,00  as_good_as_new
# 46  1072590194  20250211  12  310,00  as_good_as_new
# 47  1050597462  20250211  12  300,00  as_good_as_new
# 48  1066722758  20250211  12  325,00  as_good_as_new
# 49  1098125239  20250211   8  299,95            good
# 50  1094196062  20250211  12  280,00             new
# 51  1081465646  20250211  12  390,00             new
# 52  1050151212  20250211  12  350,00             new
# 53  1100412627  20250211   8  299,00             new
# 54  1094367879  20250211  13  350,00             new
#
#                                                nombre scrap_locat  \
# 0                                go pro black hero 10      madrid
# 1                                            gopro 10      madrid
# 2                                      gopro 10 black      madrid
# 3                                 gopro hero 10 black      madrid
# 4                    gopro hero 10 black y accesorios      madrid
# 5                                 gopro hero black 10      madrid
# 6                                      gopro 10 black      madrid
# 7                                       gopro hero 10      madrid
# 8                       cambio panasonic por gopro 10      madrid
# 9                          gopro hero 10 + accesorios      madrid
# 10                               gopro hero 10 black       madrid
# 11                                           gopro 10      madrid
# 12                                          gopro 10       madrid
# 13                gopro hero 10 black + pack max lens      madrid
# 14            gopro hero 10 con accesorios a estrenar      madrid
# 15                                gopro hero 10 black      madrid
# 16                                     gopro 10 black      madrid
# 17                                gopro hero 10 black      madrid
# 18                gopro hero 10 black con accesorios       madrid
# 19                              go pro hero 10 black       madrid
# 20                             camara go pro 10 black      madrid
# 21                                      gopro hero 10      madrid
# 22                                    gopro 11 black       madrid
# 23                                      gopro hero 11      madrid
# 24                camara ultracompacta gopro 11 black      madrid
# 25                      gopro hero 11 sin apenas uso.      madrid
# 26               gopro hero 11 black  baterias enduro      madrid
# 27                                      gopro hero 11      madrid
# 28                   gopro hero 11 black + accesorios      madrid
# 29                       gopro hero black 11 + extras      madrid
# 30                        gopro 11 black + accesorios      madrid
# 31                                gopro 11 hero black      madrid
# 32                                     gopro 11 black      madrid
# 33                              cámara gopro 11 black      madrid
# 34                                           gopro 11      madrid
# 35                                gopro 11 hero black      madrid
# 36             gopro 11 +volta + media+kit como nuevo      madrid
# 37                                gopro hero 11 black      madrid
# 38                                      gopro hero 11      madrid
# 39                               go pro hero 11 black      madrid
# 40                              go pro hero 11 black       madrid
# 41                               go pro 11 como nueva      madrid
# 42                        ⚠️gopro hero 11 naked nueva      madrid
# 43                                gopro hero 12 black      madrid
# 44                               gopro hero 12 black       madrid
# 45                               go pro hero 12 black      madrid
# 46                                           gopro 12      madrid
# 47                                gopro hero 12 naked      madrid
# 48                                         go pro 12       madrid
# 49  camara gopro hero 12 black + kit accesorios 20...      madrid
# 50                                gopro hero 12 black      madrid
# 51                        ⚠️gopro hero 12 naked nueva      madrid
# 52                                      gopro hero 12      madrid
# 53                                gopro 13 y sd 128gb      madrid
# 54                                     gopro 13 black      madrid
#
#     dist_scrap_locat  reservado  \
# 0                 60      False
# 1                 60      False
# 2                 60      False
# 3                 60      False
# 4                 60      False
# 5                 60      False
# 6                 60      False
# 7                 60      False
# 8                 60      False
# 9                 60      False
# 10                60      False
# 11                60      False
# 12                60      False
# 13                60      False
# 14                60      False
# 15                60      False
# 16                60      False
# 17                60      False
# 18                60      False
# 19                60      False
# 20                60      False
# 21                60      False
# 22                60      False
# 23                60      False
# 24                60      False
# 25                60      False
# 26                60      False
# 27                60      False
# 28                60      False
# 29                60      False
# 30                60      False
# 31                60      False
# 32                60      False
# 33                60      False
# 34                60      False
# 35                60      False
# 36                60      False
# 37                60      False
# 38                60      False
# 39                60      False
# 40                60      False
# 41                60      False
# 42                60      False
# 43                60      False
# 44                60      False
# 45                60      False
# 46                60      False
# 47                60      False
# 48                60      False
# 49                60      False
# 50                60      False
# 51                60      False
# 52                60      False
# 53                60      False
# 54                60      False
#
#                                                   url
# 0   https://es.wallapop.com/item/go-pro-black-hero...
# 1    https://es.wallapop.com/item/gopro-10-1090787536
# 2   https://es.wallapop.com/item/gopro-10-black-10...
# 3   https://es.wallapop.com/item/gopro-hero-10-bla...
# 4   https://es.wallapop.com/item/gopro-hero-10-bla...
# 5   https://es.wallapop.com/item/gopro-hero-black-...
# 6   https://es.wallapop.com/item/gopro-10-black-10...
# 7   https://es.wallapop.com/item/gooro-hero-10-107...
# 8   https://es.wallapop.com/item/cambio-panasonic-...
# 9   https://es.wallapop.com/item/gopro-hero-10---a...
# 10  https://es.wallapop.com/item/gopro-hero-10-bla...
# 11   https://es.wallapop.com/item/gopro-10-1006123008
# 12    https://es.wallapop.com/item/gopro-10-997314133
# 13  https://es.wallapop.com/item/gopro-hero-10-bla...
# 14  https://es.wallapop.com/item/gopro-10-con-acce...
# 15  https://es.wallapop.com/item/gopro-hero-10-bla...
# 16  https://es.wallapop.com/item/gopro-10-black-11...
# 17  https://es.wallapop.com/item/gopro-hero-10-bla...
# 18  https://es.wallapop.com/item/gopro-hero-10-bla...
# 19  https://es.wallapop.com/item/go-pro-hero-10-bl...
# 20  https://es.wallapop.com/item/camara-go-pro-10-...
# 21  https://es.wallapop.com/item/gopro-hero-10-103...
# 22  https://es.wallapop.com/item/gopro-11-black-10...
# 23  https://es.wallapop.com/item/gopro-hero-11-109...
# 24  https://es.wallapop.com/item/camara-ultracompa...
# 25  https://es.wallapop.com/item/gopro-hero-11-sin...
# 26  https://es.wallapop.com/item/gopro-hero-11-bla...
# 27  https://es.wallapop.com/item/gopro-hero-11-108...
# 28  https://es.wallapop.com/item/gopro-hero-11-bla...
# 29  https://es.wallapop.com/item/gopro-11---extras...
# 30  https://es.wallapop.com/item/gopro-11-black---...
# 31  https://es.wallapop.com/item/gopro-11-hero-bla...
# 32  https://es.wallapop.com/item/gopro-11-black-10...
# 33  https://es.wallapop.com/item/camara-gopro-11-b...
# 34   https://es.wallapop.com/item/gopro-11-1044882801
# 35  https://es.wallapop.com/item/gopro-11-hero-bla...
# 36  https://es.wallapop.com/item/gopro-11-kit-1012...
# 37  https://es.wallapop.com/item/gopro-hero-11-bla...
# 38  https://es.wallapop.com/item/gopro-hero-11-109...
# 39  https://es.wallapop.com/item/go-pro-hero-11-bl...
# 40  https://es.wallapop.com/item/go-pro-hero-11-bl...
# 41  https://es.wallapop.com/item/go-pro-11-como-nu...
# 42  https://es.wallapop.com/item/gopro-hero-11-nak...
# 43  https://es.wallapop.com/item/gopro-hero-12-bla...
# 44  https://es.wallapop.com/item/gopro-hero-12-bla...
# 45  https://es.wallapop.com/item/go-pro-hero-12-bl...
# 46   https://es.wallapop.com/item/gopro-12-1072590194
# 47  https://es.wallapop.com/item/gopro-hero-12-nak...
# 48  https://es.wallapop.com/item/go-pro-12-1066722758
# 49  https://es.wallapop.com/item/camara-gopro-hero...
# 50  https://es.wallapop.com/item/gopro-hero-12-bla...
# 51  https://es.wallapop.com/item/gopro-12-naked-10...
# 52  https://es.wallapop.com/item/gopro-hero-12-105...
# 53  https://es.wallapop.com/item/gopro-13-y-sd-128...
# 54  https://es.wallapop.com/item/gopro-13-black-10...

# %%
# df['tiene_color'] = df['nombre'].apply(tiene_color)
# df['tiene_emojis'] = df['nombre'].apply(tiene_emojis)
# df['tiene_revisado'] = df['nombre'].apply(tiene_revisado)

# %%
carpeta = "../3_feature_engineering"
if not os.path.exists(carpeta):
    os.makedirs(carpeta)
nombre_archivo = f"{carpeta}/gopro_{fecha}.xlsx" # excel ofrece ventajas para abrirlo en tableu. Pero no recuerdo cuales
df = df.reset_index(drop=True) # sin indice
df.to_excel(nombre_archivo, index=False)
print(nombre_archivo, "creado exitosamente")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 6
#       4 nombre_archivo = f"{carpeta}/gopro_{fecha}.xlsx" # excel ofrece ventajas para abrirlo en tableu. Pero no recuerdo cuales
#       5 df = df.reset_index(drop=True) # sin indice
# ----> 6 df.to_excel(nombre_archivo, index=False)
#       7 print(nombre_archivo, "creado exitosamente")
#
# File c:\Users\ACER\Desktop\Proyectos python\wallapop_scrapping\.env\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\ACER\Desktop\Proyectos python\wallapop_scrapping\.env\Lib\site-packages\pandas\core\generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2404 from pandas.io.formats.excel import ExcelFormatter
#    2406 formatter = ExcelFormatter(
#    2407     df,
#    2408     na_rep=na_rep,
#    (...)
#    2415     inf_rep=inf_rep,
#    2416 )
# -> 2417 formatter.write(
#    2418     excel_writer,
#    2419     sheet_name=sheet_name,
#    2420     startrow=startrow,
#    2421     startcol=startcol,
#    2422     freeze_panes=freeze_panes,
#    2423     engine=engine,
#    2424     storage_options=storage_options,
#    2425     engine_kwargs=engine_kwargs,
#    2426 )
#
# File c:\Users\ACER\Desktop\Proyectos python\wallapop_scrapping\.env\Lib\site-packages\pandas\io\formats\excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File c:\Users\ACER\Desktop\Proyectos python\wallapop_scrapping\.env\Lib\site-packages\pandas\io\excel\_openpyxl.py:57, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      44 def __init__(
#      45     self,
#      46     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#      55 ) -> None:
#      56     # Use the openpyxl module as the Excel writer.
# ---> 57     from openpyxl.workbook import Workbook
#      59     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      61     super().__init__(
#      62         path,
#      63         mode=mode,
#    (...)
#      66         engine_kwargs=engine_kwargs,
#      67     )
#
# ModuleNotFoundError: No module named 'openpyxl'
